# %%
import zwoasi as asi

# %%
asi.init("ASI_linux_mac_SDK_V1.22/lib/mac/libASICamera2.dylib")

# %%
asi.get_num_cameras()
# Out:
# 1

# %%
asi.list_cameras()
# Out:
# ['ZWO ASI071MC Pro']

# %%
cam = asi.Camera(0)

# %%
cam.get_camera_property()
# Out:
# {'Name': 'ZWO ASI071MC Pro',
#  'CameraID': 0,
#  'MaxHeight': 3284,
#  'MaxWidth': 4944,
#  'IsColorCam': True,
#  'BayerPattern': 0,
#  'SupportedBins': [1, 2, 3, 4],
#  'SupportedVideoFormat': [0, 1, 3, 2],
#  'PixelSize': 4.78,
#  'MechanicalShutter': False,
#  'ST4Port': 0,
#  'IsCoolerCam': True,
#  'IsUSB3Host': True,
#  'IsUSB3Camera': True,
#  'ElecPerADU': 2.819999933242798,
#  'BitDepth': 14,
#  'IsTriggerCam': 0}

# %%
camera.set_control_value(asi.ASI_GAIN, 150)
camera.set_control_value(asi.ASI_EXPOSURE, 3000)
camera.set_control_value(asi.ASI_WB_B, 99)
camera.set_control_value(asi.ASI_WB_R, 75)
camera.set_control_value(asi.ASI_GAMMA, 50)
camera.set_control_value(asi.ASI_BRIGHTNESS, 50)
camera.set_control_value(asi.ASI_FLIP, 0)

camera.set_image_type(asi.ASI_IMG_RGB24)

# %%
camera.capture().shape
# Out:
# (3284, 4944, 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(camera.capture(filename="temp.jpg"))
plt.colorbar()

# %%
camera.start_video_capture()

# %%
camera.stop_video_capture()

# %%
cam.get_controls()
# Out:
# {'Gain': {'Name': 'Gain',
#   'Description': 'Gain',
#   'MaxValue': 600,
#   'MinValue': 0,
#   'DefaultValue': 0,
#   'IsAutoSupported': True,
#   'IsWritable': True,
#   'ControlType': 0},
#  'Exposure': {'Name': 'Exposure',
#   'Description': 'Exposure Time(us)',
#   'MaxValue': 2000000000,
#   'MinValue': 32,
#   'DefaultValue': 10000,
#   'IsAutoSupported': True,
#   'IsWritable': True,
#   'ControlType': 1},
#  'WB_R': {'Name': 'WB_R',
#   'Description': 'White balance: Red component',
#   'MaxValue': 99,
#   'MinValue': 1,
#   'DefaultValue': 60,
#   'IsAutoSupported': True,
#   'IsWritable': True,
#   'ControlType': 3},
#  'WB_B': {'Name': 'WB_B',
#   'Description': 'White balance: Blue component',
#   'MaxValue': 99,
#   'MinValue': 1,
#   'DefaultValue': 99,
#   'IsAutoSupported': True,
#   'IsWritable': True,
#   'ControlType': 4},
#  'Offset': {'Name': 'Offset',
#   'Description': 'offset',
#   'MaxValue': 80,
#   'MinValue': 0,
#   'DefaultValue': 8,
# ...

# %%
for ctrl in cam.get_controls().values():
    print(ctrl)
# Out:
# {'Name': 'Gain', 'Description': 'Gain', 'MaxValue': 600, 'MinValue': 0, 'DefaultValue': 0, 'IsAutoSupported': True, 'IsWritable': True, 'ControlType': 0}
# {'Name': 'Exposure', 'Description': 'Exposure Time(us)', 'MaxValue': 2000000000, 'MinValue': 32, 'DefaultValue': 10000, 'IsAutoSupported': True, 'IsWritable': True, 'ControlType': 1}
# {'Name': 'WB_R', 'Description': 'White balance: Red component', 'MaxValue': 99, 'MinValue': 1, 'DefaultValue': 60, 'IsAutoSupported': True, 'IsWritable': True, 'ControlType': 3}
# {'Name': 'WB_B', 'Description': 'White balance: Blue component', 'MaxValue': 99, 'MinValue': 1, 'DefaultValue': 99, 'IsAutoSupported': True, 'IsWritable': True, 'ControlType': 4}
# {'Name': 'Offset', 'Description': 'offset', 'MaxValue': 80, 'MinValue': 0, 'DefaultValue': 8, 'IsAutoSupported': False, 'IsWritable': True, 'ControlType': 5}
# ...
